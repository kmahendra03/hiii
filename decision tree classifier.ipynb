# %% [markdown]
# # <h3>Date:</h3> <h1 style=" text-align:center;">10.DecisionTreeClassification</h1>

# %% [markdown]
# # <p style="font-size:20px; font-weight: bold; color: brown; margin: 0;">Aim:<span style="color: green;">To demonstrate the process of decision tree construction for classification problems</span></p>

# %% [markdown]
# ## Step 1: Import the breast_cancer dataset and split it into training and testing parts

# %%
from sklearn.datasets import load_wine
dataset = load_wine()
print("Feature Names:",dataset.feature_names)
print("Target class names:",dataset.target_names)
# Out:
# Feature Names: ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Target class names: ['class_0' 'class_1' 'class_2']

# %%
X = dataset.data
y = dataset.target
print("Shape of Input data:",X.shape)
print("Shape of Output data:",y.shape)
# Out:
# Shape of Input data: (178, 13)
# Shape of Output data: (178,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.9,random_state=37)
print("Training data Input shape:",X_train.shape)
print("Training data Output shape:",y_train.shape)
print("Testing data Input shape:",X_test.shape)
print("Testing data Output shape:",y_test.shape)
# Out:
# Training data Input shape: (17, 13)
# Training data Output shape: (17,)
# Testing data Input shape: (161, 13)
# Testing data Output shape: (161,)

# %% [markdown]
# ## Step 2: Build the tree
# ### Import the class *DecisionTreeClassifier* from sklearn.tree module.
# #### We can use parameter *croterion* to set the metric for the split. Possible metrics are 'gini' (default), 'entropy' or 'log_loss'.

# %%
from sklearn.tree import DecisionTreeClassifier
tree1 = DecisionTreeClassifier()
tree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
tree1 = DecisionTreeClassifier(criterion = "entropy") 
tree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ## Step 3: Evaluate the performance of the tree
#
# --> Compute both Training Accuracy and Test Accuracy to check overfitting

# %%
from sklearn.metrics import accuracy_score
training_accuracy = accuracy_score(y_train,tree1.predict(X_train))
testing_accuracy = accuracy_score(y_test,tree1.predict(X_test))
print("Training Accuracy:",training_accuracy)
print("Testing Accuracy:",testing_accuracy)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.7639751552795031

# %%
#using criterion-accuracy
from sklearn.metrics import accuracy_score
training_accuracy = accuracy_score(y_train,tree1.predict(X_train))
testing_accuracy = accuracy_score(y_test,tree1.predict(X_test))
print("Training Accuracy:",training_accuracy)
print("Testing Accuracy:",testing_accuracy)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.7639751552795031

# %% [markdown]
# # Step 4: Visualize the tree
# ### Visual tree can be generated using *sklearn.tree.export_graphviz(tree, out_file, class_names, feature_names, impurity, filled)* function. Which return a .dot file with the reqired graph.

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree1,out_file = "tree1.dot",class_names = dataset.target_names,feature_names = dataset.feature_names,impurity = True,filled = True)

# %%
from sklearn.tree import plot_tree
plot_tree(tree1,class_names=['class_0', 'class_1', 'class_2'],feature_names = dataset.feature_names,impurity =True,filled = True)
# Out:
# [Text(0.4, 0.8333333333333334, 'flavanoids <= 1.36\nentropy = 1.522\nsamples = 17\nvalue = [4, 8, 5]\nclass = class_1'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5]\nclass = class_2'),
#  Text(0.6, 0.5, 'alcohol <= 13.69\nentropy = 0.918\nsamples = 12\nvalue = [4, 8, 0]\nclass = class_1'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0]\nclass = class_1'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]\nclass = class_0')]

# %% [markdown]
# # <p style="font-size:20px; font-weight: bold; color: brown; margin: 0;">Conclusion:<span style="color: green;">Hence,the classification of wine dataset is obtained by using decision tree classifier algorithm and also visualized the generated decision tree</span></p>
